# %% [markdown]
# <a id="13"></a>
# <h1 style="background-color:#435420;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:#FF9900;">Linear Regression​</h1>
# <figcaption style="text-align: center;">
#     <strong>
#     </strong>
# </figcaption>
#
# Linear regression is a simple algorithm used to predict a target value based on one or more input features by fitting a straight line (or hyperplane in higher dimensions) to the data. It works by minimizing the difference between the predicted values and the actual values using a method called least squares. ⚡💡
#
# There are two main types:
# - Simple Regression - only one independent variable (e.g. sales)
# - Multiple Regression - more than one independent variable (e.g. sales, price)-

# %% [markdown]
# <a id="13"></a>
# <h1 style="background-color:#435420;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:#FF9900;">Step-1 Load Libraries​</h1>
# <figcaption style="text-align: center;">
#     <strong>
#     </strong>
# </figcaption>

# %%
# Load libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
""
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error , r2_score

# %% [markdown]
# <a id="13"></a>
# <h1 style="background-color:#435420;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:#FF9900;">Step-2 Load Libraries​</h1>
# <figcaption style="text-align: center;">
#     <strong>
#     </strong>
# </figcaption>

# %%
# Load Dataset
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# scatter plot of total_bill and tip
sns.scatterplot(x='total_bill' , y='tip' , data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# <a id="13"></a>
# <h1 style="background-color:#435420;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:#FF9900;">Step-3 Data Splitting​</h1>
# <figcaption style="text-align: center;">
#     <strong>
#     </strong>
# </figcaption>

# %%
# split the data into X and y
X = df[['total_bill']]
y = df['tip']

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=32)

# %% [markdown]
# <a id="13"></a>
# <h1 style="background-color:#435420;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:#FF9900;">Step-4 Linear Regression Model​</h1>
# <figcaption style="text-align: center;">
#     <strong>
#     </strong>
# </figcaption>

# %%
# call the model
model = LinearRegression()

# %%
# train the model
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# <a id="13"></a>
# <h1 style="background-color:#435420;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:#FF9900;">Step-5 Data Prediction​</h1>
# <figcaption style="text-align: center;">
#     <strong>
#     </strong>
# </figcaption>

# %%
# predict
y_pred = model.predict(X_test)
y_pred
# Out:
# array([3.05321295, 3.60451766, 3.70116071, 1.60576355, 2.74900697,
#        2.78854277, 2.3525508 , 1.72327272, 5.11017254, 3.31788314,
#        2.58976557, 3.62428556, 2.69958722, 2.56999767, 4.11958122,
#        1.88910341, 2.68201576, 2.14608609, 1.7155852 , 3.02685576,
#        2.47005997, 2.25480952, 3.73081256, 2.60184595, 2.40965806,
#        2.22296124, 2.70398009, 2.5853727 , 3.2223383 , 6.07111202,
#        3.24320441, 4.95532401, 4.12617052, 2.6446764 , 3.47382989,
#        2.58756914, 2.37122048, 2.53265831, 3.08835588, 3.44637448,
#        2.21197908, 1.57720992, 2.87640009, 1.93522851, 3.03564149,
#        2.11643424, 2.17463972, 2.73363194, 3.76595549])

# %%
# takeout model intercept and slope, make an equation
print('Intercept:', model.intercept_)
print('Coefficiant:', model.coef_)
print('y= ' ,model.intercept_ , '+' , model.coef_ , '* X')
# Out:
# Intercept: 0.7810029201694251
# Coefficiant: [0.10982165]
# y=  0.7810029201694251 + [0.10982165] * X

# %% [markdown]
# <a id="13"></a>
# <h1 style="background-color:#435420;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:#FF9900;">Step-6 Model Evaluation​</h1>
# <figcaption style="text-align: center;">
#     <strong>
#     </strong>
# </figcaption>

# %%
# evaluate the model
print('MSE: ', mean_squared_error(y_test,y_pred))
print('R2 = ', r2_score(y_test,y_pred))
print('RMSE:', np.sqrt(mean_squared_error(y_test,y_pred) ))
# Out:
# MSE:  1.23398865104845
# R2 =  0.2284848857889603
# RMSE: 1.110850417944941

# %% [markdown]
# **Insights:**
#
# - 23% r-square shows this model didn't performed well with iris dataset

# %% [markdown]
# <a id="13"></a>
# <h1 style="background-color:#435420;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:#FF9900;">Step-7 Scatter Plot in 'Original vs Predicted' data​</h1>
# <figcaption style="text-align: center;">
#     <strong>
#     </strong>
# </figcaption>

# %%
# plot the model and data 'Original vs Predicted'
plt.scatter(X_test,y_test)
plt.plot(X_test , y_pred , color = 'red')

# %% [markdown]
# **Insights:**
#
# * Blue dots shows Original dataset points
# * Red line shows best fitted line (of Predicted data)
# * If datapoints are so much far from red line
#     * Mean Square Error (MSE) will be high.
#     * Accuracy will be LOW
# * If datapoints are close to red line
#     * Mean Square Error (MSE) will be LOW.
#     * Accuracy will be HIGH

# %% [markdown]
# <a id="13"></a>
# <h1 style="background-color:#435420;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:#FF9900;">Thanks For Reading My Notebook!​</h1>
# <figcaption style="text-align: center;">
#     <strong>
#     </strong>
# </figcaption>
