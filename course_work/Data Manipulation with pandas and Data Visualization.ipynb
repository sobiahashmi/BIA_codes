# %% [markdown]
# # Basic Data Exploration

# %%
dict = {'a':1,'b':2}
res_dict = {1:'a',2:'b'}

def func(dict):
    empty_dict = {}
    for k,v in dict.items():
        empty_dict[v] = k
    return empty_dict
print(func(dict))
# invert the dictionary
# make a function
# do it in dictionary comprehension
# Out:
# {1: 'a', 2: 'b'}

# %%
# count the frequency of number and create a dictionary
input = [6, 1, 2, 2, 3, 3, 3, 4, 4, 5, 5, 5, 5]
ouput = {1:1, 2:2, 3:3, 4:2, 5:4, 6:1}

# sum dictionary
input = {
    "group1": {1, 2, 3},
    "group2": {4, 5, 6},
    "group3": {7, 8, 9}
}
output = {
    "group1": 6,
    "group2": 15,
    "group3": 24
}

empty = {}
for i, j in input.items():
   empty[i] = sum(j)
print(empty)

# Group anagrams
input = ["eat", "tea", "ate", "race", "care", "evil", "vile", "live"]
output = [["eat", "tea", "ate"],
          ["race", "care"],
          ["evil", "vile", "live"]]

# %%
# sum dictionary
input = {
    "group1": {1, 2, 3},
    "group2": {4, 5, 6},
    "group3": {7, 8, 9}
}
output = {
    "group1": 6,
    "group2": 15,
    "group3": 24
}

empty = {}
sum = 0
for i, j in input.items():
    for k in j:
      sum += k
    empty[i] = sum
    sum = 0
print(empty)
# Out:
# {'group1': 6, 'group2': 15, 'group3': 24}

# %%
input = [6, 1, 2, 2, 3, 3, 3, 4, 4, 5, 5, 5, 5]

for i in input[:3]:
    print(i)
# Out:
# 6
# 1
# 2

# %%
input = "aabcccccaaa"
output = "a2b1c5a3"

# string compression

# %% [markdown]
# ### Load the data

# %% [markdown]
# This Python code imports the pandas library, reads a CSV file into a DataFrame and displays the DataFrame's contents.

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('Data.csv')

# Display the DataFrame
display(df)
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %% [markdown]
# ### Checking Dimensions -  typically refers to examining the shape or structure of a dataset

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('data.csv')

# Check the dimensions of the DataFrame
print(df.shape)
# Out:
# (100, 13)

# %% [markdown]
# ### To view the first few rows of your DataFrame you can use the head() method.

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('data.csv')

# View the first few rows of the DataFrame
display(df.head())
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda                   -1199    (496)978-3969x58947
# ...

# %% [markdown]
# ### To generate summary statistics for your DataFrame you can use the describe() method.

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('data.csv')

# Generate summary statistics for the DataFrame
print(df.describe())
# Out:
#             Index  Numeric_Column
# count  100.000000      100.000000
# mean    50.500000       52.510000
# std     29.011492       26.881519
# min      1.000000        1.000000
# 25%     25.750000       31.500000
# 50%     50.500000       52.500000
# 75%     75.250000       73.250000
# max    100.000000       98.000000

# %% [markdown]
# ### To display the data types of each column in your DataFrame you can use the dtypes attribute.

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('data.csv')

# Display the data types of each column in the DataFrame
print(df.dtypes)
print(df['City'].dtype)
# Out:
# Index                 int64
# Customer Id          object
# First Name           object
# Last Name            object
# Company              object
# City                 object
# Country              object
# Phone 1              object
# Phone 2              object
# Email                object
# Subscription Date    object
# Website              object
# Numeric_Column        int64
# dtype: object
# object

# %% [markdown]
# ### To count the number of missing values in each column of your DataFrame you can use the isnull() method followed by the sum() method.

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('data.csv')

# Count the number of missing values in each column of the DataFrame
missing_values_count = df.isnull().sum()

print(missing_values_count)
print(df.columns)
# Out:
# Index                0
# Customer Id          0
# First Name           0
# Last Name            0
# Company              0
# City                 0
# Country              0
# Phone 1              0
# Phone 2              0
# Email                0
# Subscription Date    0
# Website              0
# Numeric_Column       0
# dtype: int64
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website', 'Numeric_Column'],
#       dtype='object')

# %% [markdown]
# ### To get the count of unique values for a categorical column in your DataFrame you can use the value_counts()

# %%
# Assuming you have already imported pandas and have your DataFrame ready
import pandas as pd

# Replace 'df' with the name of your DataFrame and 'categorical_column' with any column name from your dataset
unique_values = df['City'].value_counts()

print("Unique Values (for categorical column):")
print(unique_values)
# Out:
# Unique Values (for categorical column):
# City
# East Leonard         1
# South Julia          1
# Skinnerport          1
# East Summerstad      1
# New Jasmineshire     1
#                     ..
# West Samuel          1
# North Harold         1
# Acevedoville         1
# South Marissatown    1
# Judymouth            1
# Name: count, Length: 100, dtype: int64

# %% [markdown]
# ### To create a histogram of the data distribution for a numeric column in your DataFrame using matplotlib

# %%
import matplotlib.pyplot as plt
# Replace 'numeric_column' with the name of your numeric column
df['City'].hist()
plt.show()

# %% [markdown]
# ### Correlation: df.corr() -  calculates the correlation coefficients between all pairs of numeric columns in the DataFrame and prints the correlation matrix. Each cell in the correlation matrix represents the correlation coefficient between the corresponding pair of columns. The correlation coefficient ranges from -1 to 1, where:
#
# - 1 indicates a perfect positive correlation,
# - -1 indicates a perfect negative correlation, and
# - 0 indicates no correlation.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install seaborn

# Sample data
data = {
    'A': [1, 2, 3, 4, 5],
    'B': [5, 4, 3, 2, 1],
    'C': [2, 3, 4, 5, 6],
    'D': [3, 2, 5, 4, 1]
}

# Create DataFrame
df = pd.DataFrame(data)
display(df)

# Calculate correlation matrix
correlation_matrix = df.corr()

# Print correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)

# Plot correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix')
plt.show()
# Out:
#    A  B  C  D
# 0  1  5  2  3
# 1  2  4  3  2
# 2  3  3  4  5
# 3  4  2  5  4
# 4  5  1  6  1
# Correlation Matrix:
#      A    B    C    D
# A  1.0 -1.0  1.0 -0.2
# B -1.0  1.0 -1.0  0.2
# C  1.0 -1.0  1.0 -0.2
# D -0.2  0.2 -0.2  1.0

# %% [markdown]
# ### This command generates a box plot for the column named 'numeric_column' in the DataFrame. A box plot visually represents the distribution of numerical data and helps identify outliers, if any.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Creating sample data
data = {
    'numeric_column': np.random.normal(loc=30, scale=10, size=100)  # Generating 100 random numbers with mean 50 and standard deviation 10
}
df1 = pd.DataFrame(data) 

# Outliers (box plot):
df1.boxplot(column='numeric_column')

# Show the plot
plt.show()

# %% [markdown]
# ### A scatter plot is a type of data visualization that displays the relationship between two numerical variables by representing each data point as a dot on a two-dimensional plane.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Creating sample data
np.random.seed(0)
data = {
    'x': np.random.randn(100),  # Generating 100 random numbers for the x-axis
    'y': np.random.randn(100),  # Generating 100 random numbers for the y-axis
}
df = pd.DataFrame(data)

# Visualization (scatter plot)
plt.scatter(df['x'], df['y'])
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatter Plot Example with Random Data')
plt.show()

# %% [markdown]
# ### Deletion

# %% [markdown]
# ### Remove rows with missing values

# %%
import pandas as pd

# Sample DataFrame with missing values
data = {'A': [1, 2, None, 4, 5],
        'B': [None, 6, 7, 8, 9],
        'C': [10, 11, 12, None, 14]}

df = pd.DataFrame(data)

print("Original DataFrame:")
print(df)

# Remove rows with missing values
df.dropna(inplace=True)
print("\nDataFrame after removing rows with missing values:")
print(df)
# Out:
# Original DataFrame:
#      A    B     C
# 0  1.0  NaN  10.0
# 1  2.0  6.0  11.0
# 2  NaN  7.0  12.0
# 3  4.0  8.0   NaN
# 4  5.0  9.0  14.0
#
# DataFrame after removing rows with missing values:
#      A    B     C
# 1  2.0  6.0  11.0
# 4  5.0  9.0  14.0

# %% [markdown]
# ### Remove columns with many missing values

# %%
import pandas as pd

# Sample DataFrame with missing values
data = {'A': [1, 2, None, 4, 5],
        'B': [None, 6, 7, 8, 9],
        'C': [10, 11, 12, None, 14]}

df = pd.DataFrame(data)

print("Original DataFrame:")
print(df)

# Remove columns with many missing values
df.drop('B', axis=1, inplace=True)
print("\nDataFrame after removing column 'B' with many missing values:")
print(df)
# Out:
# Original DataFrame:
#      A    B     C
# 0  1.0  NaN  10.0
# 1  2.0  6.0  11.0
# 2  NaN  7.0  12.0
# 3  4.0  8.0   NaN
# 4  5.0  9.0  14.0
#
# DataFrame after removing column 'B' with many missing values:
#      A     C
# 0  1.0  10.0
# 1  2.0  11.0
# 2  NaN  12.0
# 3  4.0   NaN
# 4  5.0  14.0

# %% [markdown]
# ### Imputation

# %% [markdown]
# ### Forward or backward Fill missing values with the mean

# %% [markdown]
# ### Forward Fill - In the forward fill method, missing values are filled with the last observed non-null value in each column.

# %%
import pandas as pd
import numpy as np

# Create sample DataFrame with missing values
data = {'A': [1, np.nan, 3, np.nan, 5],
        'B': [np.nan, 2, np.nan, 4, np.nan]}
df = pd.DataFrame(data)
print(df)

# Forward fill missing values
df_ffill = df.ffill()
df_new = df_ffill.bfill()
print("DataFrame after forward fill:")
print(df_new)
# Out:
#      A    B
# 0  1.0  NaN
# 1  NaN  2.0
# 2  3.0  NaN
# 3  NaN  4.0
# 4  5.0  NaN
# DataFrame after forward fill:
#      A    B
# 0  1.0  2.0
# 1  1.0  2.0
# 2  3.0  2.0
# 3  3.0  4.0
# 4  5.0  4.0

# %% [markdown]
# ### Backward Fill - In the backward fill method, missing values are filled with the next observed non-null value in each column.

# %%
import pandas as pd
import numpy as np

# Create sample DataFrame with missing values
data = {'A': [1, np.nan, 3, np.nan, 5],
        'B': [np.nan, 2, np.nan, 4, np.nan]}
df = pd.DataFrame(data)

# Backward fill missing values
df_bfill = df.bfill()
print("\nDataFrame after backward fill:")
print(df_bfill)
# Out:
# DataFrame after backward fill:
#      A    B
# 0  1.0  2.0
# 1  3.0  2.0
# 2  3.0  4.0
# 3  5.0  4.0
# 4  5.0  NaN

# %% [markdown]
# ### Indicator Variables

# %% [markdown]
# ### In the context of missing data, indicator variables can be used to flag whether a certain value is missing or not. This can be helpful for analysis and modeling, as missing data often needs to be handled or accounted for in some way.

# %% [markdown]
# ### This code creates a new column named 'column_name_missing' in the DataFrame. The purpose of this column is to indicate whether the corresponding value in the column 'column_name' is missing or not.

# %%
import pandas as pd

# Sample data
data = {'column_name': [10, 20, None, 30, None, 40]}
df = pd.DataFrame(data)

# Indicator Variables
df['column_name_missing'] = df['column_name'].isnull()

print(df)
# Out:
#    column_name  column_name_missing
# 0         10.0                False
# 1         20.0                False
# 2          NaN                 True
# 3         30.0                False
# 4          NaN                 True
# 5         40.0                False

# %% [markdown]
# # Creating Basic Plot

# %% [markdown]
# ### Line plot

# %% [markdown]
# A line plot is a type of graph that displays data points connected by straight lines. It is commonly used to visualize the relationship between two variables over a continuous interval.

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 14, 8, 20, 12]

# Create a line plot
plt.plot(x, y, marker='p', linestyle='--', color='g', label='Line Plot')

# Adding labels and a title
plt.xlabel('X-axis')  # Label for the X-axis
plt.ylabel('Y-axis')  # Label for the Y-axis
plt.title('Line Plot Example')  # Title of the plot

# Adding a legend
plt.legend()  # Show the legend with label specified in the plot

# Show the plot
plt.show()  # Display the plot

# %% [markdown]
# ### Scatter plot

# %% [markdown]
# A scatter plot is a type of data visualization that displays the relationship between two variables by representing data points as individual dots on a two-dimensional plane

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 14, 8, 20, 12]

# Create a scatter plot
plt.scatter(x, y, marker='o', color='r', label='Scatter Plot')

# Adding labels and a legend
plt.xlabel('X-axis')  # Label for the X-axis
plt.ylabel('Y-axis')  # Label for the Y-axis
plt.title('Scatter Plot Example')  # Title of the plot
plt.legend()  # Show legend

# Show the plot
plt.show()

# %% [markdown]
# ### Bar Chart

# %% [markdown]
# A bar chart is a type of graph that presents categorical data with rectangular bars. The length or height of each bar is proportional to the value it represents.

# %%
import matplotlib.pyplot as plt

# Sample data
categories = ['Category A', 'Category B', 'Category C', 'Category D']
values = [15, 24, 20, 30]

# Create a bar chart
plt.bar(categories, values, color='m', alpha=0.80, label='Bar Chart')

# Adding labels and a legend
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart Example')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Customizing plot

# %% [markdown]
# ### xlabel() and ylabel(): Add labels to the x-axis and y-axis.

# %%
import matplotlib.pyplot as plt

# Sample data
x_values = [1, 2, 3, 4, 5]
y_values = [10, 14, 8, 20, 12]

# Create a scatter plot
plt.scatter(x_values, y_values, marker='o', color='r', label='Scatter Plot')

# Adding labels to the x-axis and y-axis
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')

# Set a title for the plot
plt.title('Scatter Plot Example')

# Show the plot
plt.show()

# %% [markdown]
# ### legend(): Display a legend to distinguish multiple

# %%
import matplotlib.pyplot as plt

# Sample data for two series
x1 = [1, 2, 3, 4, 5]
y1 = [10, 14, 8, 20, 12]
x2 = [1, 2, 3, 4, 5]
y2 = [5, 8, 12, 10, 15]

# Create line plots for two series with labels
plt.plot(x1, y1, marker='o', linestyle='-', color='b', label='Series 1')
plt.plot(x2, y2, marker='s', linestyle='--', color='r', label='Series 2')

# Add a legend to distinguish the two series
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# ### Color: Change the line or marker color.

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 14, 8, 20, 12]

# Create a line plot with blue color
plt.plot(x, y, color='blue')

# Display the plot
plt.show()

# %% [markdown]
# ### linestyle: Modify the line style

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 14, 8, 20, 12]

# Create a line plot with dashed linestyle
plt.plot(x, y, linestyle='--')

# Display the plot
plt.show()

# %% [markdown]
# ### Marker: Specify markers

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 14, 8, 20, 12]

# Create a scatter plot with circular markers
plt.scatter(x, y, marker='s')

# Display the plot
plt.show()

# %% [markdown]
# ### linewidth: Adjust the line width.

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 14, 8, 20, 12]

# Create a line plot with adjusted line width
plt.plot(x, y, linewidth=2)

# Display the plot
plt.show()

# %% [markdown]
# ### markersize: Change the size of markers.

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 14, 8, 20, 12]

# Create a scatter plot with adjusted marker size
plt.scatter(x, y, marker='o', s=80)

# Display the plot
plt.show()

# %% [markdown]
# ### xlim() and ylim(): Set specific limits for the x-axis and y-axis.

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 14, 8, 20, 12]

# Create a scatter plot
plt.scatter(x, y, marker='o')

# Set specific limits for the x-axis and y-axis
plt.xlim(0, 10)  # Set x-axis limits from 0 to 10
plt.ylim(0, 30)  # Set y-axis limits from 0 to 30

# Display the plot
plt.show()

# %% [markdown]
# ### grid(): Add grid lines to the plot.

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 14, 8, 20, 12]

# Create a scatter plot
plt.scatter(x, y, marker='o')

# Add grid lines to the plot
plt.grid(True)

# Display the plot
plt.show()

# %% [markdown]
# ### text(): Add text annotations to the plot.

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 14, 8, 20, 12]

# Create a scatter plot
plt.scatter(x, y, marker='o')

# Add text annotation to the plot
plt.text(2, 25, 'Annotation Text', fontsize=12, color='red')

# Display the plot
plt.show()

# %% [markdown]
# ### figure(): Adjust the figure size.

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 14, 8, 20, 12]

# Adjust figure size
plt.figure(figsize=(12, 12))

# Create a scatter plot
plt.scatter(x, y, marker='o')

# Add text annotation to the plot
plt.text(2, 25, 'Annotation Text', fontsize=12, color='red')

# Display the plot
plt.show()

# %% [markdown]
# #  Saving Plots

# %% [markdown]
#  - Import Matplotlib.
#  - Create your plot using plt.plot(), plt.scatter(), or any other plot function.
#  - Customize the plot as needed (e.g., add labels and a title).
#  - Use plt.savefig() to save the plot as an image file. You provide the file name with the desired file extension (e.g., 'my_plot.png', 'my_plot.pdf').

# %% [markdown]
# ### Save the plot as an image file (e.g., PNG)

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 14, 8, 20, 12]

# Create a scatter plot
plt.scatter(x, y, marker='o')

# Add text annotation to the plot
plt.text(2, 25, 'Annotation Text', fontsize=12, color='red')

# Save the plot as an image file (PNG)
plt.savefig('my_plot.png')

# Display the plot
plt.show()

# %% [markdown]
# ### Save as PDF

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 14, 8, 20, 12]

# Create a scatter plot
plt.scatter(x, y, marker='o')

# Save the plot as a PDF file
plt.savefig('my_plot.pdf')

# Display the plot
plt.show()

# %% [markdown]
# # Seaborn

# %% [markdown]
# ### Seaborn is a data visualization library.
#  - Built on top of Matplotlib.
#  - Designed for creating beautiful and informative statistical plots.

# %% [markdown]
# ### Creating Statistical Plots

# %% [markdown]
# ### Histogram

# %% [markdown]
# A histogram is a graphical representation of the distribution of numerical data. It consists of a series of adjacent rectangles, or bins, each representing a specific interval or range of values, and the height of each rectangle corresponds to the frequency, or count, of data points falling within that interval.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
data = sns.load_dataset("iris")

print(type(data))
print(data.shape)
print(data.columns)
display(data.head(10))

# Create a histogram
sns.histplot(data=data, x="sepal_length", kde=True)

# Adding labels and a title
plt.xlabel("Sepal Length")
plt.ylabel("Frequency")
plt.title("Histogram of Sepal Length")

# Show the plot
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (150, 5)
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %% [markdown]
# ### Box Plot

# %% [markdown]
# A box plot is a method for graphically depicting groups of numerical data through their quartiles, providing a visual summary of the distribution, outliers, and variability.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
data = sns.load_dataset("tips")

# Create a box plot
sns.boxplot(data=data, x="day", y="total_bill", palette="Set2")

# Adding labels and a title
plt.xlabel("Day")
plt.ylabel("Total Bill")
plt.title("Box Plot of Total Bill by Day")

# Show the plot
plt.show()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# ### Violin Plot

# %% [markdown]
# A violin plot is a method of plotting numeric data and can be considered a combination of a box plot and a kernel density plot. It displays the distribution of the data across different levels of a categorical variable.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
data = sns.load_dataset("tips")

# Create a violin plot
sns.violinplot(data=data, x="day", y="total_bill", palette="pastel")

# Adding labels and a title
plt.xlabel("Day")
plt.ylabel("Total Bill")
plt.title("Violin Plot of Total Bill by Day")

# Show the plot
plt.show()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# ### Pair plot

# %% [markdown]
# A pair plot, also known as a scatterplot matrix, is a grid of scatterplots that displays the pairwise relationships between variables in a dataset. Each scatterplot in the grid represents the relationship between two variables, allowing for visual examination of potential correlations and patterns across multiple variables simultaneously. It's a useful tool for exploring the relationships between multiple variables in a dataset.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load a sample dataset
data = sns.load_dataset("iris")

# Create a pair plot
sns.pairplot(data, hue="species", markers=["o", "s", "D"])

# Show the plot
plt.show()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ### Heat Map

# %% [markdown]
# A heatmap is a graphical representation of data where values in a matrix are represented as colors. It's particularly useful for visualizing relationships between two variables in a dataset. In a heatmap, each cell in the matrix is assigned a color based on its value. The colors typically range from dark (representing low values) to light (representing high values), allowing patterns and trends to be easily identified.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Load the "tips" dataset
data = sns.load_dataset("tips")
# Select relevant numeric columns
numeric_data = data[['total_bill', 'tip', 'size']]
# Calculate the correlation matrix
correlation_matrix = numeric_data.corr()
# Create a heat map
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
# Show the plot
plt.show()
